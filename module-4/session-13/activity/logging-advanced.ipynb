# %% [markdown]
# # Content
# 1. Debug with prints
# 2. Debug Example with Logging
# 3. Basic saving logging with logging
# 4. Format logs
# 5. Configure one file to Log
# 6. Separate file Logs
# 7. Handlers, Formatters y Streams
# 8. Custom Logging
# 9. Resources

# %% [markdown]
# # Setup
# 1. Only run the following cell to save the code of the basic operations of the calculator.

# %%
# %%writefile calculadora.py
def obtener_fracciones(frac_str):
    if isinstance(frac_str, int) or isinstance(frac_str, float):
        return frac_str

    if "/" in frac_str:
        try:
            return float(frac_str)
        except ValueError:
            num, denom = frac_str.split("/")
            try:
                leading, num = num.split(" ")
                whole = float(leading)
            except ValueError:
                whole = 0
            frac = float(num) / float(denom)
            return whole - frac if whole < 0 else whole + frac
    else:
        return float(frac_str)


def sum(a, b):
    sumando_a = obtener_fracciones(a)
    sumando_b = obtener_fracciones(b)
    return sumando_a + sumando_b


def subtract(a, b):
    minuendo = obtener_fracciones(a)
    sustraendo = obtener_fracciones(b)
    return minuendo - sustraendo


def multiply(a, b):
    multiplicando = obtener_fracciones(a)
    multiplicador = obtener_fracciones(b)
    return multiplicando * multiplicador


def divide(a, b):
    dividendo = obtener_fracciones(a)
    divisor = obtener_fracciones(b)
    try:
        return dividendo / divisor
    except ZeroDivisionError:
        return "Division entre cero"
# Out:
# Writing calculadora.py

# %% [markdown]
# # Debug con prints

# %% [markdown]
# Execute the following code to prove that the operations work correctly. And also to clear calls to operations.

# %%
import calculadora as calc

# %%
import calculadora as calc

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  return calc.multiply(v1,v2)

num_1 = 20
num_2 = 10

add_result = get_sum(num_1, num_2)
print(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
print(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
print(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
print(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Add: 20 + 10 = 30
# Sub: 20 - 10 = 10
# Mul: 20 * 10 = 200
# Div: 20 / 10 = 2.0

# %%
# %%writefile debug_prints.py
import calculadora as calc

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  return calc.multiply(v1,v2)

num_1 = 20
num_2 = 10

add_result = get_sum(num_1, num_2)
print(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
print(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
print(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
print(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Writing debug_prints.py

# %%
# !python debug_prints.py
# Out:
# Add: 20 + 10 = 30
# Sub: 20 - 10 = 10
# Mul: 20 * 10 = 200
# Div: 20 / 10 = 2.0

# %% [markdown]
# # Debug con logging

# %% [markdown]
# To debug correctly, the `logging` dependency is used. And is used as seen in the code: `logging.debug ("My message) `.

# %%
# %%writefile debug_logging.py
import logging
import calculadora as calc

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  return calc.multiply(v1,v2)

num_1 = 20
num_2 = 10

add_result = get_sum(num_1, num_2)
logging.debug(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logging.debug(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logging.debug(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logging.debug(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Writing debug_logging.py

# %%
# !python debug_logging.py

# %% [markdown]
# Nothing happens, Logging's default configuration is WARNING. You will only throw WARNINGS or CRITICAL.
#
# It is necessary to change the filter level.

# %%
# %%writefile debug_logging.py
import logging 
import calculadora as calc


logging.basicConfig(level=logging.DEBUG) 

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  logging.debug(f"v1: {v1}")
  logging.debug(f"v2: {v2}")
  return calc.multiply(v1,v2)

num_1 = 20
num_2 = 10

add_result = get_sum(num_1, num_2)
logging.debug(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logging.debug(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logging.info(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logging.debug(f"Div: {num_1} / {num_2} = {div_result}")
logging.warning("Mensaje de WARNING")
logging.error("Mensaje de ERROR")
# Out:
# Overwriting debug_logging.py

# %%
# !python debug_logging.py
# Out:
# DEBUG:root:Add: 20 + 10 = 30
# DEBUG:root:Sub: 20 - 10 = 10
# DEBUG:root:v1: 20
# DEBUG:root:v2: 10
# INFO:root:Mul: 20 * 10 = 200
# DEBUG:root:Div: 20 / 10 = 2.0
# WARNING:root:Mensaje de WARNING
# ERROR:root:Mensaje de ERROR

# %% [markdown]
# We can see as based on the hierarchy of the Logs, from DEBUG level everything up they start to be saved.

# %% [markdown]
# **Exercise**
#
# Modify `logging.debug` a `logging.warning`, changing the configuration levels.

# %% [markdown]
# # Logs saving

# %%
# %%writefile save_logs.py
import logging 
import calculadora as calc

logging.basicConfig(filename="test.log", level=logging.INFO) 

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  logging.debug(f"v1: {v1}")
  logging.debug(f"v2: {v2}")
  return calc.multiply(v1,v2)

num_1 = 4
num_2 = 9

add_result = get_sum(num_1, num_2)
logging.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logging.info(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logging.info(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logging.info(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Overwriting save_logs.py

# %%
# !python save_logs.py

# %% [markdown]
# **Exercise**
#
# Open the file and identify the lines.
#
# Then, change the entry numbers, the level configuration to `level=logging.INFO`, and `logging.debug` to `logging.info`.
#
# Execute the script and check `test.log`.

# %% [markdown]
# # Format logs

# %%
# %%writefile format_logs.py

import logging 
import calculadora as calc

logging.basicConfig(filename='test_format.log', level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  logging.debug(f"v1: {v1}")
  logging.debug(f"v2: {v2}")
  return calc.multiply(v1,v2)

num_1 = 4
num_2 = 9

add_result = get_sum(num_1, num_2)
logging.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logging.info(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logging.info(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logging.info(f"Div: {num_1} / {num_2} = {div_result}")
logging.info("www.google.com")
# Out:
# Writing format_logs.py

# %%
# !python format_logs.py

# %% [markdown]
# **Exercise**:
#
# Try placing the name of the module and the name of the file to the logs.
#
# Check more info here [Record attributes](https://docs.python.org/3/library/logging.html#logrecord-attributes)

# %% [markdown]
# # Configuring one Log file

# %%
# %%writefile employee.py
import logging

logging.basicConfig(filename='employee.log', level=logging.INFO,
                    format='%(asctime)s:%(module)s:%(levelname)s:%(message)s')

class Employee:
    """A sample Employee class"""

    def __init__(self, first, last):
        self.first = first
        self.last = last

        logging.info(f"Created Employee: {self.fullname} - {self.email}")

    @property
    def email(self):
        return f"{self.first}.{self.last}@email.com"

    @property
    def fullname(self):
        return f"{self.first} {self.last}"


emp_1 = Employee("John", "Smith")
emp_2 = Employee("Corey", "Schafer")
emp_3 = Employee("Jane", "Doe")
# Out:
# Writing employee.py

# %% [markdown]
# The `@property` decorator is used to define a property in a class in Python.

# %%
# !python employee.py

# %% [markdown]
# Execute the following code that includes imports the `employee` module.

# %%
# %%writefile include_other_module.py

import logging 
import calculadora as calc
import employee

logging.basicConfig(filename='test_format.log', level=logging.DEBUG,
                    format='%(asctime)s:%(module)s:%(levelname)s:%(message)s')

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  logging.debug(f"v1: {v1}")
  logging.debug(f"v2: {v2}")
  return calc.multiply(v1,v2)

num_1 = 4
num_2 = 9

add_result = get_sum(num_1, num_2)
logging.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logging.info(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logging.info(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logging.info(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Writing include_other_module.py

# %%
# !python include_other_module.py

# %% [markdown]
# Open the `employee.log` file is observed how the calculator logs were written in that file.
#
# Although the `include_other_module.py` script has declared a log focused on` test_format.log`, the `employee.py` will be taken as a root log.
#
# **Exercise**
#
# Change the level in the `Employee.py` a` Warning`. Check the logs both in `test_format.log` and in` Employee.log`.
#
# The logs will continue to appear even when the level has settled to `WARNING`.This is because the script will continue to take as a reference to `employee.py` as the RAIZ file.

# %% [markdown]
# # Splitting Log files

# %% [markdown]
# A good practice is to have a log for each module.
#
# To do this, first you have to create a `logger` instance, and configure it to take the name of the module as follows:
#
# ```python
# my_logger = logging.getLogger(__name__)
# ```

# %%
# %%writefile employee.py
import logging

logger = logging.getLogger(__name__) # Indicamos que tome el nombre del modulo
logger.setLevel(logging.DEBUG) # Configuramos el nivel de logging

formatter = logging.Formatter('%(asctime)s:%(name)s:%(module)s:%(levelname)s:%(message)s') # Creamos el formato

file_handler = logging.FileHandler('employee.log') # Indicamos el nombre del archivo

file_handler.setFormatter(formatter) # Configuramos el formato

logger.addHandler(file_handler) # Agregamos el archivo

class Employee:
    """A sample Employee class"""

    def __init__(self, first, last):
        self.first = first
        self.last = last

        # Cambiar el logging por logger
        logger.info(f"Created Employee: {self.fullname} - {self.email}")

    @property
    def email(self):
        return f"{self.first}.{self.last}@email.com"

    @property
    def fullname(self):
        return f"{self.first} {self.last}"


emp_1 = Employee("John", "Smith")
emp_2 = Employee("Corey", "Schafer")
emp_3 = Employee("Jane", "Doe")
# Out:
# Overwriting employee.py

# %%
# !python employee.py

# %%
# %%writefile include_other_module.py

import logging 
import calculadora as calc
import employee

logging.basicConfig(filename='test_format.log', level=logging.DEBUG,
                    format='%(asctime)s:%(name)s:%(module)s:%(levelname)s:%(message)s')

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  logging.debug(f"v1: {v1}")
  logging.debug(f"v2: {v2}")
  return calc.multiply(v1,v2)

num_1 = 4
num_2 = 9

add_result = get_sum(num_1, num_2)
logging.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logging.info(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logging.info(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logging.info(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Overwriting include_other_module.py

# %%
# !python include_other_module.py

# %% [markdown]
# If everything works correctly, we can see that now the `employee` logs are created in a different file as well as those of `test_format`.
#
# Check the name of the modules (name) has changed, can have `__main__`,` employee` and `root`, depends on the module that has initialized it.

# %% [markdown]
# Now, we are going to change the `include_other_module.py` too. Do not forget to change `logging` for` logger`.

# %%
# %%writefile include_other_module.py

import logging 
import calculadora as calc
import employee

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(asctime)s:%(name)s:%(module)s:%(levelname)s:%(message)s')

file_handler = logging.FileHandler('test_format.log')
file_handler.setFormatter(formatter)

logger.addHandler(file_handler)

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  return calc.divide(v1,v2)

def get_multiplication(v1,v2):
  logger.debug(f"v1: {v1}")
  logger.debug(f"v2: {v2}")
  return calc.multiply(v1,v2)

num_1 = 4
num_2 = 9

add_result = get_sum(num_1, num_2)
logger.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logger.info(f"Sub: {num_1} - {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logger.info(f"Mul: {num_1} * {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logger.info(f"Div: {num_1} / {num_2} = {div_result}")
# Out:
# Overwriting include_other_module.py

# %%
# !python include_other_module.py

# %% [markdown]
# ### Log Exceptions

# %% [markdown]
# When we want to include the exceptions traceback, like this:
# ```bash
# Traceback (most recent call last):
#   File "my_module.py", line 24, in function_name
#     something...
# MyError: Error description
# ```
#
# We have to add the exception, and then include the `logger.exception('Our message')` code, as shown below.
#
# When the exception occurs, the traceback will be saved in the logs.
#
# Test by changing both `num_1` and` num_2` to `0`, and check the log file.

# %%
# %%writefile include_other_module.py

import logging 
import calculadora as calc
import employee

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s:%(name)s:%(module)s:%(levelname)s:%(message)s')

file_handler = logging.FileHandler('include_other_module.log')
file_handler.setFormatter(formatter)

logger.addHandler(file_handler)

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  try: 
    result = v1/v2
  except ZeroDivisionError:
      logger.exception('Tried to divide by zero')
  else:
      return result

def get_multiplication(v1,v2):
  return calc.multiply(v1,v2)

num_1 = 0
num_2 = 0

add_result = get_sum(num_1, num_2)
logger.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logger.info(f"Sub: {num_1} + {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logger.info(f"Mul: {num_1} + {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logger.info(f"Div: {num_1} + {num_2} = {div_result}")
# Out:
# Overwriting include_other_module.py

# %%
# !python include_other_module.py

# %% [markdown]
# ### Save logs and stream in console

# %% [markdown]
# If we want to save the logs, and also print them on console, we must add `logging.streamhandler ()`, as shown in the code.

# %%
# %%writefile include_other_module.py

import logging 
import calculadora as calc
import employee

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(asctime)s:%(name)s:%(message)s')

file_handler = logging.FileHandler('include_other_module.log')
file_handler.setFormatter(formatter)

# THIS IS THE NEW CHANGE TO STREAM LOGS
stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.addHandler(stream_handler) # Se agrega handler para stream

def get_sum(v1,v2):
  return calc.sum(v1,v2)

def get_subtract(v1,v2):
  return calc.subtract(v1,v2)

def get_division(v1,v2):
  try: 
    result = v1/v2
  except ZeroDivisionError:
      logger.exception('Tried to divide by zero')
  else:
      return result

def get_multiplication(v1,v2):
  return calc.multiply(v1,v2)

num_1 = 23
num_2 = 45

add_result = get_sum(num_1, num_2)
logger.info(f"Add: {num_1} + {num_2} = {add_result}")

sub_result = get_subtract(num_1, num_2)
logger.info(f"Sub: {num_1} + {num_2} = {sub_result}")

mul_result = get_multiplication(num_1, num_2)
logger.info(f"Mul: {num_1} + {num_2} = {mul_result}")

div_result = get_division(num_1, num_2)
logger.info(f"Div: {num_1} + {num_2} = {div_result}")
# Out:
# Overwriting include_other_module.py

# %%
# !python include_other_module.py
# Out:
# 2022-10-22 15:50:09,369:__main__:Add: 23 + 45 = 68
# 2022-10-22 15:50:09,369:__main__:Sub: 23 + 45 = -22
# 2022-10-22 15:50:09,369:__main__:Mul: 23 + 45 = 1035
# 2022-10-22 15:50:09,370:__main__:Div: 23 + 45 = 0.5111111111111111

# %% [markdown]
# # Custom Logging

# %% [markdown]
# There are advanced ways of customizing logs, they are described below. It is only enough to execute each of the outputs described below.

# %%
# %%writefile logger.py
import logging
import sys

class CustomFormatter(logging.Formatter):
    """Logging Formatter to add colors and count warning / errors"""

    grey = "\x1b[38;21m"
    yellow = "\x1b[33;21m"
    red = "\x1b[31;21m"
    bold_red = "\x1b[31;1m"
    reset = "\x1b[0m"
    format = "%(asctime)s - %(name)s - %(levelname)s - %(message)s (%(filename)s:%(lineno)d)"

    FORMATS = {
        logging.DEBUG: grey + format + reset,
        logging.INFO: grey + format + reset,
        logging.WARNING: yellow + format + reset,
        logging.ERROR: red + format + reset,
        logging.CRITICAL: bold_red + format + reset
    }

    def format(self, record):
        log_fmt = self.FORMATS.get(record.levelno)
        formatter = logging.Formatter(log_fmt)
        return formatter.format(record)

# create logger with 'spam_application'
logger = logging.getLogger("Sample")

# create console handler with a higher log level
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)

if len(sys.argv)> 1:
    if sys.argv[1] == 'log':
        ch.setFormatter(logging.Formatter('%(asctime)s : %(levelname)s : %(name)s : %(message)s'))
    elif sys.argv[1] == 'color':
        ch.setFormatter(CustomFormatter())

if len(sys.argv) > 2:
    logger.setLevel(logging.__getattribute__(sys.argv[2]))
else:
    logger.setLevel(logging.DEBUG)

logger.addHandler(ch)

# logger.debug("debug message")
# logger.info("info message")
# logger.warning("warning message")
# logger.error("error message")
# logger.critical("critical message")

import random
import time
for _ in range(100):
    i = random.randint(0, 10)
    if i <= 4:
        logger.info("Value is {} - Everything is fine".format(i))
    elif i <= 6:
        logger.warning("Value is {} - System is getting hot".format(i))
    elif i <= 8:
        logger.error("Value is {} - Dangerous region".format(i))
    else:
        logger.critical("Maximum value reached")
    time.sleep(0.3)
# Out:
# Writing logger.py

# %% [markdown]
# **Raw output as with just prints**

# %%
# !python logger.py
# Out:
# Value is 5 - System is getting hot
# Maximum value reached
# Value is 8 - Dangerous region
# Value is 6 - System is getting hot
# Maximum value reached
# Value is 7 - Dangerous region
# Value is 2 - Everything is fine
# Value is 8 - Dangerous region
# Value is 1 - Everything is fine
# Maximum value reached
# Value is 2 - Everything is fine
# Value is 2 - Everything is fine
# Value is 0 - Everything is fine
# Value is 1 - Everything is fine
# Maximum value reached
# Maximum value reached
# Value is 0 - Everything is fine
# Value is 1 - Everything is fine
# Value is 1 - Everything is fine
# Maximum value reached
# Value is 5 - System is getting hot
# Value is 4 - Everything is fine
# Value is 6 - System is getting hot
# Value is 8 - Dangerous region
# Value is 6 - System is getting hot
# Value is 3 - Everything is fine
# Value is 8 - Dangerous region
# Value is 3 - Everything is fine
# Value is 8 - Dangerous region
# Maximum value reached
# Maximum value reached
# ...

# %% [markdown]
# **Log formatted output**

# %%
# !python logger.py log
# Out:
# 2022-10-21 17:20:23,083 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:20:23,384 : WARNING : Sample : Value is 6 - System is getting hot
# 2022-10-21 17:20:23,684 : INFO : Sample : Value is 4 - Everything is fine
# 2022-10-21 17:20:23,985 : ERROR : Sample : Value is 7 - Dangerous region
# 2022-10-21 17:20:24,286 : WARNING : Sample : Value is 5 - System is getting hot
# 2022-10-21 17:20:24,586 : INFO : Sample : Value is 4 - Everything is fine
# 2022-10-21 17:20:24,887 : INFO : Sample : Value is 3 - Everything is fine
# 2022-10-21 17:20:25,188 : INFO : Sample : Value is 4 - Everything is fine
# 2022-10-21 17:20:25,488 : WARNING : Sample : Value is 6 - System is getting hot
# 2022-10-21 17:20:25,789 : WARNING : Sample : Value is 5 - System is getting hot
# 2022-10-21 17:20:26,089 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:20:26,390 : INFO : Sample : Value is 2 - Everything is fine
# ...

# %% [markdown]
# **Print only ERROR levels and above**

# %%
# !python logger.py log ERROR
# Out:
# 2022-10-21 17:20:57,036 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:20:59,139 : ERROR : Sample : Value is 7 - Dangerous region
# 2022-10-21 17:21:01,543 : ERROR : Sample : Value is 7 - Dangerous region
# 2022-10-21 17:21:01,843 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:21:02,445 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:21:02,745 : CRITICAL : Sample : Maximum value reached
# 2022-10-21 17:21:03,046 : CRITICAL : Sample : Maximum value reached
# 2022-10-21 17:21:03,346 : CRITICAL : Sample : Maximum value reached
# 2022-10-21 17:21:03,647 : CRITICAL : Sample : Maximum value reached
# 2022-10-21 17:21:04,849 : ERROR : Sample : Value is 7 - Dangerous region
# 2022-10-21 17:21:07,253 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:21:07,855 : ERROR : Sample : Value is 8 - Dangerous region
# 2022-10-21 17:21:08,155 : CRITICAL : Sample : Maximum value reached
# ...

# %% [markdown]
# **Color formatted output**

# %%
# !python logger.py color
# Out:
# 2022-10-21 17:21:26,715 - Sample - INFO - Value is 3 - Everything is fine (logger.py:58)
# 2022-10-21 17:21:27,015 - Sample - WARNING - Value is 5 - System is getting hot (logger.py:60)
# 2022-10-21 17:21:27,316 - Sample - ERROR - Value is 8 - Dangerous region (logger.py:62)
# 2022-10-21 17:21:27,617 - Sample - WARNING - Value is 6 - System is getting hot (logger.py:60)
# 2022-10-21 17:21:27,917 - Sample - ERROR - Value is 7 - Dangerous region (logger.py:62)
# 2022-10-21 17:21:28,218 - Sample - ERROR - Value is 7 - Dangerous region (logger.py:62)
# 2022-10-21 17:21:28,519 - Sample - INFO - Value is 2 - Everything is fine (logger.py:58)
# 2022-10-21 17:21:28,819 - Sample - INFO - Value is 3 - Everything is fine (logger.py:58)
# 2022-10-21 17:21:29,120 - Sample - ERROR - Value is 7 - Dangerous region (logger.py:62)
# 2022-10-21 17:21:29,420 - Sample - INFO - Value is 3 - Everything is fine (logger.py:58)
# ...

# %% [markdown]
# # Resources

# %% [markdown]
# * [Logging: Instalación de logging para Python](https://docs.python.org/es/3/library/logging.html)
# * [Python Tutorial: Logging Basics - Logging to Files, Setting Levels, and Formatting
# ](https://www.youtube.com/watch?v=-ARI4Cz-awo)
# * [Python Tutorial: Logging Advanced - Loggers, Handlers, and Formatters](https://www.youtube.com/watch?v=jxmzY9soFXg)
