# %% [markdown]
# # PROGRAMACIÓN ORIENTADA A OBJETOS (POO)
#
# # Contenido
# * Introduccion a POO
# 1. Objetos en Python
#   * 1.1 Objetos
#   * 1.2 Clases
# 2. Propiedades y métodos
#   * 2.1 Propiedades/atributos
#   * 2.2 Métodos
# 3. `self` e `__init__()`
#   * 3.1 `self`
#   * 3.2 `__init__()`
#   * 3.3 Ejemplo
# 4. Herencia
#   * 4.1 Herencia simple
#   * 4.2 Herencia múltiple
# 5. Polimorfismo
#   * 5.1 Polimorfismo y herencia (anulacion de métodos)
# 6. BaseEstimator y TransformerMixin de scikit-learn
#   * 6.1 - Qué es scikit-learn?
#   * 6.2 - Transformación de datos y transformadores personalizados
#   * 6.3 - Clase BaseEstimator y Clase TransformerMixin
#   * 6.4 - Ejemplo: Obtener mean (promedio) y std (desviación estandar)
# 7. Ejemplo
# 8. Ejercicio

# %% [markdown]
# # 0. Introduccion a POO
#
# La programación orientada a objetos se basa en el concepto de crear un modelo del problema de destino en sus programas. La programación orientada a objetos disminuye los errores y promociona la reutilización del código.
#
# Python es un lenguaje de programación orientado a objetos.
# Casi todo en Python es un objeto, con sus propiedades y métodos.
# Una clase es como un constructor de objetos o un "modelo" para crear objetos.

# %% [markdown]
# ## 0.1  ¿Por qué usar POO?
# Muchas cosas se pueden lograr hacer con Python mientras el codigo sea simple y facil de entender. Pero conforme los proyectos se van volviendo mas grandes y complejos, sera necesario encontrar una forma de mantener los programas y la informacion organizados, estructurados, faciles de modificar en cuanto haya nuevos integrantes en el equipo de trabajo, o se vayan agregando nuevas características.
#
# Es aqui donde POO puede ayudar bastante a crear programas modulares, faciles de planificar, mantener y aprender por nuevos programadores.

# %% [markdown]
# # 1 - Objetos en Python

# %% [markdown]
# ## 1.1 - Objetos
# > Los objetos pueden no ser cosas tangibles que puedas captar o sentir, mas bien, son modelos de algo que puede hacer ciertas cosas y que tambien están sujetos a que se les hagan ciertas cosas. Formalmente, **un objeto es una colección de datos y comportamientos asociados**.
#
# > Cada objeto, de igual modo que la entidad de la vida real a la que representa, tiene un estado (es decir, unos atributos con unos valores concretos) y un comportamiento (es decir, tiene funcionalidades o sabe hacer unas acciones concretas).
#
# **Ejemplo de objeto: un auto.**
#
# > La clase se representa por una plantilla o esqueleto a partir del cual se creará el auto.
#
# > Cuando se fabrica el auto, se le considera como un objeto, totalmente diferenciado del pavimento en donde está estacionado.
#
# > Sus **atributos/propiedades** son su color, marca, modelo, número de matrícula, número de puertas, etc.
#
# > Los **métodos** son todo aquello que nos ofrece el auto, como hacer sonar una bocina cuando tocamos el claxon, llevarnos por la carretera, reducir la velocidad al pisar el freno, etc.

# %% [markdown]
# ## 1.2 - Clases
#
# > Podemos definir informalmente una clase como una plantilla (o esqueleto o plano) a partir de la cual se crean los objetos.
#
# > En términos más formales, una clase es una descripción de un objeto. Consta de una serie de métodos y datos que resumen las características de este objeto. Definir clases permite trabajar con código reutilizable. Puesto que desde una clase se puede crear una instancia y así reutilizar el código escrito para esta si tener que volver a escribir el código para la instancia. La instancia toma el patrón de la clase padre. Sin embargo, las variables son idependientes.

# %%
class MiClase: # 1)
  atributo_1 = 5 # 2)

# %% [markdown]
# En los puntos se definen:
# * 1) Se define la clase con el nombre `Auto`
# * 2) Se define un atributo `atributo_1` (se explica a continuación).

# %% [markdown]
# # 2 - Propiedades/atributos y métodos

# %% [markdown]
# ## 2.1 - Propiedades/atributos
#
# Las propiedades, también llamadas campos o atributos, son variables que codifican el estado de un objeto. Es decir, son características que aplican al objeto, por ejemplo: el aspecto que refleja, el color, tamaño, posición, si está o no habilitado, etc.

# %%
class Auto: # 1)
  kilometraje = 1000 # 2)
  marca = "Nissan" # 3)
  modelo = "March" # 4)

# %% [markdown]
# En el codigo de arriba:
# * 1) Se define la clase con el nombre `Auto`
# * 2) Se define el atributo `kilometraje` igual a 1000
# * 3) Se define el atributo `marca` igual a "Nissan"
# * 2) Se define el atributo `modelo` igual a "March

# %% [markdown]
# ## 2.2 - Métodos
#
# Los métodos son aquellas funciones que permite efectuar el objeto y que nos rinden algún tipo de servicio durante el transcurso del programa.
# Determinan a su vez como va a responder el objeto cuando recibe un mensaje.
#
# **Nota**
#
# Un método es parte de una clase, es decir, es parte de la funcionalidad que le damos a un objeto. Por tanto, siempre va a estar asociado a un objeto.

# %%
class Auto: # 1)
  kilometraje = 1000 # 2)
  marca = "Nissan" # 3)
  modelo = "March" # 4)

  def encender_auto(self): # 5)
    print("Auto encendido")

  def apagar_auto(self): # 6)
    print("Auto apagado")

# %% [markdown]
# En el codigo de arriba:
# * 1), 2), 3) y 4) ya fueron explicados en **Propiedades/atributos**
# * 5) Se define el método `encender_auto()`, así como el parámetro `self` (que se explica a continuación).
# * 6) Se define el método `apagar_auto()`, así como el parámetro `self` (que se explica a continuación).

# %% [markdown]
# # 3 - `self` and `__init__()`

# %% [markdown]
# ## 3.1 - `self`
# El parámetro `self` es una referencia a la instancia actual de la clase y se utiliza para acceder a las variables que pertenecen a la clase.
#
# No tiene que llamarse `self`, puedes llamarlo como quieras, pero tiene que ser el primer parámetro de cualquier método en la clase:

# %% [markdown]
# ## 3.2 - `__init__()`
#
# Para comprender el significado de las clases en Python, debemos entender primero el método incorporada `__init__()` .
#
# Todas las clases tienen un método llamad `__init__()`, que siempre se ejecuta cuando se inicia la clase.
#
# Se usa el método `__init__()` para asignar valores a las propiedades del objeto u otras operaciones que sean necesarias cuando se crea el mismo.

# %%
class Persona:
  def __init__(self, nombre, edad): # 1)
    self.nombre = nombre
    self.edad = edad

  def mi_metodo(self): # 2)
    print("Hola, mi nombre es " + self.nombre + " y mi edad es " + str(self.edad))

p1 = Persona(nombre="Carlos", edad="27") # 3)
#p1 = Persona("Carlos", "27") # 3)
print(p1.nombre)
print(p1.edad)
p1.mi_metodo() # 4)
# Out:
# Carlos
# 27
# Hola, mi nombre es Carlos y mi edad es 27

# %%
class Persona:
  def __init__(miobjeto): # 1)
    pass

  def mi_metodo(abc): # 2)
    print("Hola, mi nombre es Carlos")

p1 = Persona() # 3)
p1.mi_metodo() # 4)
# Out:
# Hola, mi nombre es Carlos

# %% [markdown]
# En el codigo anterior:
# * 1) Usamos la palabra `miobjeto` en lugar de `self`.
# * 2) Usamos la palabra `abc`  en lugar de `self`.
# * 3) Creamos una instancia de la clase Persona y le pasamos como argumentos el nombre "Carlos" y la edad 26.
# * 4) Llamamos al método definido `mi_metodo()` que imprime el nombre y la edad.
#
# **Nota**
#
# En la definición de un método los valores que se reciben se denominan *parámetros*, pero durante la llamada los valores que se envían se denominan *argumentos*.

# %% [markdown]
# ##3.3 - Ejemplos

# %%
class Auto: # 1)
  def __init__(self, color, marca, modelo, matricula="none"): # 2)
    self.color = color # 3)
    self.marca = marca # 4)
    self.modelo = modelo # 5)
    self.matricula = matricula # 6)

  def encender_auto(self): # 7)
    print("Auto encendido")

  def apagar_auto(self): # 8)
    print("Auto apagado")

a1 = Auto(color="Azul",marca= "Nissan", modelo= "2010", matricula= 1234) # 9)

print(a1.color) # 10)
print(a1.marca) # 11)
print(a1.modelo) # 12)
print(a1.matricula) # 13)
a1.encender_auto() # 14)
a1.apagar_auto() # 15)
# Out:
# Azul
# Nissan
# 2010
# 1234
# Auto encendido
# Auto apagado

# %% [markdown]
# En el código arriba, se explica que es lo que sucede punto por punto:
# * 1) Se define la clase auto
# * 2) Se llama al método `__init__()` de la clase auto, y toma cuatro argumentos: self (la instancia, es por default), color (un texto), marca (un texto) y modelo (otro texto), y matrícula (número).
# * 3), 4), 5) y 6) Aquí se establecen los valores de los atributos "color", "marca", "modelo" y "matrícula", para que sean iguales al nombre del argumento pasado al crear un objeto.
# * 7) Se define el método `encender_auto()`, solo con el parámetro por default `self`. En este método no escribiremos otro parámetro. Solo va a imprimir un mensaje de "Auto encendido".
# * 8) Se define el método `apagar_auto()`, solo con el parámetro por default `self`. En este método no escribiremos otro parámetro. Solo va a imprimir un mensaje de "Auto apagado".
# * 9) Cuando se usa una llamada de constructor, es decir, se crea una instancia del objeto, se hace como lo ilustra el código: a1 = Auto("Azul", "Nissan", "Versa", 1234), donde:
# > * *Azul* sería asignado como valor para el atributo "color".
# > * *Nissan* sería el valor asignado para el atributo "marca".
# > * *Versa* sería el valor asignado para el atributo "modelo".
# > * *1234* sería el valor asignado para el atributo "matricula".
#
# * 10), 11), 12) y 13) Se imprimen los atributos del objeto que creado.
# * 14) y 15) Se llaman a los métodos del objeto `encender_auto()` y `apagar_auto()`.

# %% [markdown]
# # 4 - Herencia
# Es la capacidad de una clase de heredar atributos y métodos de otra, además de agregar nuevos y/o modificar los existentes.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.1 Herencia simple
# Revise las clases debajo y la forma de instanciarlas, pasando argumentos para crear objetos.

# %%
class Libro:
  def __init__(self, titulo, precio, autor, paginas):
      self.titulo = titulo
      self.precio = precio
      self.autor = autor
      self.paginas = paginas

class Revista:
  def __init__(self, titulo, precio, periodo, editor):
      self.titulo = titulo
      self.precio = precio
      self.periodo = periodo
      self.editor = editor

class Periodico:
  def __init__(self, titulo, precio, periodo, editor):
      self.titulo = titulo
      self.precio = precio
      self.periodo = periodo
      self.editor = editor

l1 = Libro(titulo="100 años de soledad", autor="Gabriel Garcia Marquez", paginas=300, precio=300.0)
r1 = Revista(titulo="Ciencias", editor="UNAM", precio=0, periodo="Mensual")
p1 = Periodico("El Financiero.", 3.0,"Grupo Multimedia Lauman", "Diario")

print(l1.autor)
print(p1.editor)
print(l1.precio, p1.precio, r1.precio)
# Out:
# Gabriel Garcia Marquez
# Diario
# 300.0 3.0 0

# %%
print(r1.titulo)
print(r1.precio)
print(r1.periodo)
print(r1.editor)
# Out:
# Ciencias
# 0
# Mensual
# UNAM

# %% [markdown]
# Aunque el codigo funciona muy bien, hay atributos en las clases que estan duplicados. Las tres clases tienen los atributos `titulo` y `precio`. Mientras que la clase `Revista` y `Periodico` tienen los atributos `periodo` y `editor`.
#
# Para organizar el codigo de estas clases, y permitir que nuevas puedan ser agregadas en el futuro, vamos a ordenar el codigo. El resultado se refleja en la celda de abajo.

# %%
class Publicacion:
  def __init__(self, titulo, precio):
      self.titulo = titulo
      self.precio = precio

class Libro(Publicacion):
  def __init__(self, titulo, precio, autor, paginas):
    super().__init__(titulo, precio)
    self.autor = autor
    self.paginas = paginas

class Periodico(Publicacion):
  def __init__(self, titulo, precio, periodo, editor):
      super().__init__(titulo, precio)
      self.periodo = periodo
      self.editor = editor

class Revista(Periodico):
  def __init__(self, titulo, precio, periodo, editor):
      super().__init__(titulo, precio, periodo, editor)

# %%
libro = Libro("Sapiens", 500, "Yuval Noah", 443)
print(libro.precio, libro.titulo, libro.autor, libro.paginas)
# Out:
# 500 Sapiens Yuval Noah 443

# %%
periodico = Periodico("El Financiero", 10, "Diario", "Grupo Multimedia Lauman")
print(periodico.titulo, periodico.precio, periodico.periodo, periodico.editor)
# Out:
# El Financiero 10 Diario Grupo Multimedia Lauman

# %%
revista = Revista("Ciencias", 0, "Mensual", "UNAM")
print(revista.titulo, revista.precio, revista.periodo, revista.editor)
# Out:
# Ciencias 0 Mensual UNAM

# %% [markdown]
# `super()` es un método en Python que nos permite llamar a un método en una clase principal. Esto puede ser útil para la herencia múltiple, donde puede usar super para llamar a un método en una clase principal que no es el último elemento en el orden de resolución del método.

# %% [markdown]
# ## 4.2 Herencia multiple
# La herencia múltiple permite heredar métodos y atributos de dos o más clases base.
#
#
# A continuacion se observa un ejemplo de herencia múltiple.

# %%
class A:
  def __init__(self):
    super().__init__()
    self.foo = "foo"
    self.name = "Clase A"

  def mensaje(self):
    print("En Clase A")

class B:
  def __init__(self):
    super().__init__()
    self.bar = "bar"
    self.name = "Clase B"

  def mensaje(self):
    print("En Clase B")


class C(A, B):
  def __init__(self):
    super().__init__()

  def show_attribs(self):
    print(self.foo)
    print(self.bar)
    print(self.name)

  def mensaje(self): # Anulación de metodo de clase base
    print("En Clase C")


c = C()
print(C.__mro__)
c.show_attribs()
c.mensaje()
# Out:
# (<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>)
# foo
# bar
# Clase A
# En Clase C

# %%
dir(C)

# %%
x = 5
dir(x)

# %% [markdown]
# **Notas**
#
# El MRO es el orden en que se busca un método en la jerarquía de clases. Es una secuencia que usa Python para encontrar un método en una clase. Es principalmente útil en el caso de la herencia para buscar un método en las clases principales.
#
# La clase `object` es el ancestro de cada clase en Python. Si hace `object.__bases__`, obtendrá un valor vacío.
#
# En Python 2.x, todavía es obligatorio heredar explícitamente objetos como la clase `BaseClass(object)`, pero desde Python 3.x, ya no es necesario. Es generado por default.

# %% [markdown]
# # 5 - Polimorfismo

# %% [markdown]
# El polimorfismo es la técnica que nos posibilita que al invocar un determinado método de un objeto, podrán obtenerse distintos resultados según la clase del objeto. Esto se debe a que distintos objetos pueden tener un método con un mismo nombre, pero que realice distintas operaciones.

# %%
print(len("polimorfismo"))
print(len([1,2,3]))
# Out:
# 12
# 3

# %%
class Gato:
	def hablar(self):
		print("MIAU")

class Perro:
	def hablar(self):
		print("GUAU")

def escuchar_mascota(animal):
	animal.hablar()

gato = Gato()
perro = Perro()

escuchar_mascota(gato)
escuchar_mascota(perro)
# Out:
# MIAU
# GUAU

# %% [markdown]
# Podemos llamar a la función `escuchar_mascota()` pasando como algo argumento, en este caso el animal. Luego, a ese algo se la llama su función `hablar()`, aún cuando esta venga de diferentes clases. Esto es **polimorfismo**.

# %% [markdown]
# ## 5.1 Polimorfismo y Herencia
# El polimorfismo nos permite definir métodos en la clase secundaria que tienen el mismo nombre que los métodos en la clase principal.
#
#
# En la herencia, la clase secundaria hereda los métodos de la clase principal. Sin embargo, **es posible modificar un método en una clase secundaria que haya heredado de la clase principal**.
#
#
# Esto es particularmente útil en los casos en que el método heredado de la clase principal no se ajusta del todo a la clase secundaria. En tales casos, volvemos a implementar el método en la clase secundaria.

# %%
class Ave:
  def intro(self):
    print("Hay muchos tipos de aves.")

  def flight(self):
    print("La mayoria de las aves pueden volar, pero otras no.")

class Buho(Ave):
  def flight(self):
    print("Los buhos pueden volar.")

class Pinguino(Ave):
  def flight(self):
    print("Los pinguinos no pueden volar.")

ave = Ave()
buho = Buho()
pinguino = Pinguino()

ave.intro()
ave.flight()
print("---------")
buho.intro()
buho.flight()
print("---------")
pinguino.intro()
pinguino.flight()
# Out:
# Hay muchos tipos de aves.
# La mayoria de las aves pueden volar, pero otras no.
# ---------
# Hay muchos tipos de aves.
# Los buhos pueden volar.
# ---------
# Hay muchos tipos de aves.
# Los pinguinos no pueden volar.

# %% [markdown]
# **EJEMPLO - TODOS LOS TEMAS**

# %% [markdown]
# Clase simple con atributios y self

# %% [markdown]
# ![Diagrama en blanco (1).png](data:image/png;base64,...)

# %%
class Ingeniero:
  def __init__(self, nombre, edad, experiencia):
    print("Hola soy un Ingeniero")
    self.nombre = nombre
    self.edad = edad
    self.experiencia = experiencia

ingeniero_sistemas = Ingeniero("Aurora", 30, 5)

print(ingeniero_sistemas.nombre)
print(ingeniero_sistemas.edad)
print(ingeniero_sistemas.experiencia)

print("-----------------------------------------")

ingeniero_civil = Ingeniero("Raul", 3, 9)
print(ingeniero_civil.nombre)
print(ingeniero_civil.edad)
print(ingeniero_civil.experiencia)
# Out:
# Hola soy un Ingeniero
# Aurora
# 30
# 5
# -----------------------------------------
# Hola soy un Ingeniero
# Raul
# 3
# 9

# %% [markdown]
# Clase simple con atributos, self y metodos

# %%
class Ingeniero:
  def __init__(self, nombre, edad, experiencia, especialidad):
    print("Hola soy un Ingeniero")
    self.nombre = nombre
    self.edad = edad
    self.experiencia = experiencia
    self.especialidad = especialidad

  def especialidad_metodo(self):
    print("Mi especialidad es: ", self.especialidad)
    return True

ingeniero_sistemas = Ingeniero("Aurora", 30, 5, "Python")

print(ingeniero_sistemas.nombre)
print(ingeniero_sistemas.edad)
print(ingeniero_sistemas.experiencia)
print(ingeniero_sistemas.especialidad_metodo())

print("-----------------------------------------")

ingeniero_civil = Ingeniero("Raul", 3, 9, "Ingenieria estructural")
print(ingeniero_civil.nombre)
print(ingeniero_civil.edad)
print(ingeniero_civil.experiencia)
print(ingeniero_civil.especialidad_metodo())
# Out:
# Hola soy un Ingeniero
# Aurora
# 30
# 5
# Mi especialidad es:  Python
# True
# -----------------------------------------
# Hola soy un Ingeniero
# Raul
# 3
# 9
# Mi especialidad es:  Ingenieria estructural
# True

# %% [markdown]
# Super Clase con atributos, self y metodos Herencia Multiple

# %%
class Ads_downloader:
  def __init__(self, token, api_name, file_path_output, url_request):
    print("Entrando a Ads_downloader")
    self.token = token
    self.api_name = api_name
    self.file_path_output = file_path_output
    self.url_request = url_request
    self.start_time = "2023-07-26"
    self.end_time = "2023-07-27"

  def authenticate(self):
    print("Autenticando Credenciales para ", self.api_name)

  def create_request(self):
    print("Creando request a URL: ", self.url_request, "para fecha: ", self.start_time, "-",self.end_time)

  def download_file(self):

    print("Descargando Archivo en ", self.file_path_output)

  def create_download_flow(self):
    self.authenticate()
    self.create_request()
    self.download_file()
    return "Descarga exitosa."

class Create_tables:
  def __init__(self, file_path_output):
    print("Entrando a Create_tables")
    self.file_path_output = file_path_output

  def clean_file(self):
    return "Limpiando Archivo que se encuentra en: ",self.file_path_output

  def create_table(self):
    return "Creando Tabla."


class Instagram_ads_downloader(Ads_downloader,Create_tables):
  def __init__(self, token, api_name, file_path_output, url_request, partition_field):
    super().__init__(token, api_name, file_path_output, url_request)
    self.partition_field = partition_field

instagram_object = Instagram_ads_downloader("123abc","instagram","user/instagram/reports/daily","www.instagram/reports.com","date")
print(instagram_object.create_download_flow())
print(instagram_object.clean_file())
print(instagram_object.create_table())
print(instagram_object.partition_field)
# Out:
# Entrando a Ads_downloader
# Autenticando Credenciales para  instagram
# Creando request a URL:  www.instagram/reports.com para fecha:  2023-07-26 - 2023-07-27
# Descargando Archivo en  user/instagram/reports/daily
# Descarga exitosa.
# ('Limpiando Archivo que se encuentra en: ', 'user/instagram/reports/daily')
# Creando Tabla.
# date

# %% [markdown]
# SUper Clase con atributos, self, metodos, Herencia Multiple y sobre-escritura

# %%
class Ads_downloader:
  def __init__(self, token, api_name, file_path_output, url_request):
    print("Entrando a Ads_downloader")
    self.token = token
    self.api_name = api_name
    self.file_path_output = file_path_output
    self.url_request = url_request
    self.start_time = "2023-07-26"
    self.end_time = "2023-07-27"

  def authenticate(self):
    print("Autenticando Credenciales para ", self.api_name)

  def create_request(self):
    print("Creando request a URL: ", self.url_request, "para fecha: ", self.start_time, "-",self.end_time)

  def download_file(self):

    print("Descargando Archivo en ", self.file_path_output)

  def create_download_flow(self):
    self.authenticate()
    self.create_request()
    self.download_file()
    return "Descarga exitosa."

class Create_tables:
  def __init__(self, file_path_output):
    print("Entrando a Create_tables")
    self.file_path_output = file_path_output

  def clean_file(self):
    return "Limpiando Archivo que se encuentra en: ",self.file_path_output

  def create_table(self):
    return "Creando Tabla."

class Amazon_ads_downloader(Ads_downloader, Create_tables):
    def __init__(self, token, api_name, file_path_output, url_request, partition_field):
        super().__init__(token, api_name, file_path_output, url_request)
        self.partition_field = partition_field

    def authenticate(self):
      print("Sobreescribiendo metodo para autenticar")
      return True


amazon_object = Amazon_ads_downloader("123abc", "amazon", "user/amazon/reports/daily", "www.amazon/reports.com", "date")
print(amazon_object.create_download_flow())
print(amazon_object.clean_file())
print(amazon_object.create_table())
# Out:
# Entrando a Ads_downloader
# Sobreescribiendo metodo para autenticar
# Creando request a URL:  www.amazon/reports.com para fecha:  2023-07-26 - 2023-07-27
# Descargando Archivo en  user/amazon/reports/daily
# Descarga exitosa.
# ('Limpiando Archivo que se encuentra en: ', 'user/amazon/reports/daily')
# Creando Tabla.

# %% [markdown]
# # Fuentes
# * https://docs.python.org/es/3/tutorial/classes.html
# * https://www.w3schools.com/python/python_classes.asp
# * Dusty Phillips. “Python 3 Object-Oriented Programming.”
# * https://www.upv.es/amiga/43.htm
# * https://www.ibm.com/docs/es/spss-modeler/SaaS?topic=language-object-oriented-programming
# * https://ichi.pro/es/desarrollo-de-transformadores-y-estimadores-scikit-learn-personalizados-269625218773307
# * https://towardsdatascience.com/understand-inheritance-in-python-74f8e3025f3c
# * https://sklearn-template.readthedocs.io/en/latest/user_guide.html
# * https://stackoverflow.com/questions/66521182/explaination-for-a-code-snippet-related-to-classes-in-python

# %%
class Hola():
  def __init__(self):
    self.__secret = "secret"
    self._internal_attrib = "internal"
    self.external_attrib = "external"

class Hello(Hola):
  def __init__(self):
    super().__init__()
    self.world = "hello world"

hola = Hola()
print(hola.external_attrib)
print(hola._internal_attrib)
print(hola._Hola__secret)

hello = Hello()
print(dir(hello))
print(hello._internal_attrib)
print(hello._Hola__secret)
# Out:
# external
# internal
# secret
# ['_Hola__secret', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_internal_attrib', 'external_attrib', 'world']
# internal
# secret

# %% [markdown]
# # Notas
# `@classmethod`
#
# * Un método de clase es un método que está vinculado a la clase y no al objeto de la clase.
#
# * Tienen acceso al estado de la clase ya que toma un parámetro de clase que apunta a la clase y no a la instancia del objeto.
#
# * Puede modificar un estado de clase que se aplicaría en todas las instancias de la clase. Por ejemplo, puede modificar una variable de clase que será aplicable a todas las instancias.
